# %%
# Face Recognition
# Importing the libraries
import cv2
# Loading the cascades
## Loading the Trained Models
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')
# Defining a function that will do the detections
def detect(gray, frame):
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
# detectMultiScale #
#1. Image
#2. Scaling Factor
#3. No of neighbouring pixels to be considered to detect
    for (x, y, w, h) in faces:
#print(faces)
#print("Number of faces detected: " + str(faces.shape[0]))
        cv2.putText(frame, "Number of faces detected: " + str(faces.shape[0]), (10, 30),
        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
# Put Text #
#1.Image, 2.Text we want to display, 3.Position of the text (x,y), 4.Font, 5.Font S
#7.Thikness
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)
# Rectangle #
# Image, Starting Point, Ending Point, color of box, width of box
## Saving the box and Images ##
        roi_color = frame[y:y+h, x:x+w]
#FaceFileName = "face_" + str(y) + ".jpg"
#cv2.imwrite(FaceFileName, roi_color)
    return frame

# %%
# Doing some Face Recognition with the webcam
video_capture = cv2.VideoCapture(0)
while True:
    data,frame = video_capture.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    canvas = detect(gray, frame)
    cv2.imshow('Video', canvas)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
video_capture.release()
cv2.destroyAllWindows()

# %%
import cv2
# Loading the cascades
## Loading the Trained Models
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')
smile_cascade = cv2.CascadeClassifier('haarcascade_smile.xml')

# %%
img = cv2.imread("sis-love.JPG")
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
cv2.imshow("Pic",img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
eyes = eye_cascade.detectMultiScale(gray, 1.3, 5)
smile = smile_cascade.detectMultiScale(gray, 1.3, 5)

# %%
faces
# Out:
# array([[365, 181,  85,  85],
#        [530, 163,  85,  85]])

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (255,255,253), 2)
    cv2.putText(img, "face", (x, y),
    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (250, 239, 88), 2)
for (ex, ey, ew, eh) in eyes:
    cv2.rectangle(img, (ex,ey), (ex+ew, ey+eh), (102,102,255), 2)
for i in smile:
    if len(smile)>1:
        cv2.putText(img, "Smiling",(x,y-30), cv2.FONT_HERSHEY_SIMPLEX,0.5, (0,255,0),2)

# %%
cv2.imshow("Pic",img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
import cv2
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')
smile_cascade = cv2.CascadeClassifier('haarcascade_smile.xml')
def detect(gray, frame):
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    eyes = eye_cascade.detectMultiScale(gray, 1.3, 5)
    smile = smile_cascade.detectMultiScale(gray, 1.3, 15)
    for (x, y, w, h) in faces:
        cv2.putText(frame, "Number of faces detected: " + str(faces.shape[0]), (10, 20),
        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)
        for (ex, ey, ew, eh) in eyes:
            cv2.putText(frame, "Number of eyes detected:" + str(eyes.shape[0]),(10,60),
                       cv2.FONT_HERSHEY_SIMPLEX,0.5, (255,0,0),2)
            cv2.rectangle(frame, (ex,ey), (ex+ew, ey+eh), (102,102,255), 2)
            for i in smile:
                if len(smile)>1:
                    cv2.putText(frame, "Smiling",(x,y-30), cv2.FONT_HERSHEY_SIMPLEX,0.5, (0,255,0),2)
                roi_color = frame[y:y+h, x:x+w]
    return frame

# %%
# Doing some Face Recognition with the webcam
video_capture = cv2.VideoCapture(0)
while True:
    data,frame = video_capture.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    canvas = detect(gray, frame)
    cv2.imshow('Video', canvas)
    if cv2.waitKey(1) & 0xFF == ord('s'):
        break
video_capture.release()
cv2.destroyAllWindows()
